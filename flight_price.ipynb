# %% [markdown]
# these are the important libraries which we need to call before performing EDA

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %% [markdown]
# now performing EDA process step by step and knowing about the dataset

# %%
df=pd.read_excel('Data_Train.xlsx')
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.tail()
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10678              CCU → BLR    19:55        22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %% [markdown]
# finding out that is there any null values in the columns of the dataset

# %%
df.isnull()
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0        False            False   False        False  False     False
# 1        False            False   False        False  False     False
# 2        False            False   False        False  False     False
# 3        False            False   False        False  False     False
# 4        False            False   False        False  False     False
# ...        ...              ...     ...          ...    ...       ...
# 10678    False            False   False        False  False     False
# 10679    False            False   False        False  False     False
# 10680    False            False   False        False  False     False
# 10681    False            False   False        False  False     False
# 10682    False            False   False        False  False     False
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# 0             False     False        False            False  False
# 1             False     False        False            False  False
# 2             False     False        False            False  False
# 3             False     False        False            False  False
# 4             False     False        False            False  False
# ...             ...       ...          ...              ...    ...
# 10678         False     False        False            False  False
# 10679         False     False        False            False  False
# 10680         False     False        False            False  False
# 10681         False     False        False            False  False
# 10682         False     False        False            False  False
#
# [10683 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum().value_counts()
# Out:
# 0    9
# 1    2
# dtype: int64

# %% [markdown]
# as there are null values present in the two columns but the two columns are of object datatype so we have to left
# the null values as it is

# %% [markdown]
# the columns of dataset are of object datatype so we have to convert the datatype by using label encoder into numeric datatype.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0            3               24       0            5     18       211
# 1            1                6       3            0     84        31
# 2            4               43       2            1    118        70
# 3            3               10       3            0     91       164
# 4            3                0       0            5     29       149
# ...        ...              ...     ...          ...    ...       ...
# 10678        0               41       3            0     64       183
# 10679        1               29       3            0     64       193
# 10680        4               29       0            2     18        58
# 10681       10                0       0            5     18        92
# 10682        1               42       2            1    108        85
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# 0               233       240            4                8   3897
# 1               906       336            1                8   7662
# 2               413       106            1                8  13882
# 3              1324       311            0                8   6218
# 4              1237       303            0                8  13302
# ...             ...       ...          ...              ...    ...
# 10678          1259       236            4                8   4107
# 10679          1305       237            4                8   4145
# 10680           824       280            4                8   7229
# 10681           938       238            4                8  12648
# 10682          1124       347            1                8  11753
#
# [10683 rows x 11 columns]

# %% [markdown]
# the statistical view of the dataset

# %%
df.describe()
# Out:
#             Airline  Date_of_Journey        Source   Destination  \
# count  10683.000000     10683.000000  10683.000000  10683.000000
# mean       3.965927        23.735093      1.952261      1.436113
# std        2.352155        12.337763      1.177221      1.474782
# min        0.000000         0.000000      0.000000      0.000000
# 25%        3.000000        14.000000      2.000000      0.000000
# 50%        4.000000        24.000000      2.000000      1.000000
# 75%        4.000000        35.000000      3.000000      2.000000
# max       11.000000        43.000000      4.000000      5.000000
#
#               Route      Dep_Time  Arrival_Time      Duration   Total_Stops  \
# count  10683.000000  10683.000000  10683.000000  10683.000000  10683.000000
# mean      74.825143    107.980717    869.828419    194.069269      1.458579
# std       36.730924     61.085563    331.509504    108.620556      1.806560
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       48.000000     55.000000    603.000000    106.000000      0.000000
# 50%       73.000000     96.000000    937.000000    233.000000      0.000000
# 75%      104.000000    164.000000   1141.000000    280.000000      4.000000
# max      128.000000    221.000000   1342.000000    367.000000      5.000000
#
#        Additional_Info         Price
# count     10683.000000  10683.000000
# mean          7.393054   9087.064121
# std           1.214211   4611.359167
# min           0.000000   1759.000000
# 25%           8.000000   5277.000000
# 50%           8.000000   8372.000000
# 75%           8.000000  12373.000000
# max           9.000000  79512.000000

# %% [markdown]
# knowing the mean ,median and minimum ,maximum values of the columns

# %% [markdown]
# seeing the correlation between the columns and with the target columns and also presenting the heatmap for better understanding

# %%
dfcor=df.corr()
dfcor
# Out:
#                   Airline  Date_of_Journey    Source  Destination     Route  \
# Airline          1.000000         0.022251 -0.013401     0.018479  0.025039
# Date_of_Journey  0.022251         1.000000  0.167549    -0.273357  0.275233
# Source          -0.013401         0.167549  1.000000    -0.592574  0.403378
# Destination      0.018479        -0.273357 -0.592574     1.000000 -0.461169
# Route            0.025039         0.275233  0.403378    -0.461169  1.000000
# Dep_Time        -0.039439        -0.007836  0.055191    -0.063608 -0.082080
# Arrival_Time    -0.015733        -0.012507  0.020844    -0.036830  0.010523
# Duration         0.027917        -0.001168 -0.192009     0.022037 -0.062111
# Total_Stops      0.035732        -0.043846 -0.225557     0.337756 -0.437362
# Additional_Info -0.060802         0.008382 -0.022107     0.026806  0.035216
# Price           -0.039520        -0.036942  0.015998    -0.071112  0.164085
#
#                  Dep_Time  Arrival_Time  Duration  Total_Stops  \
# Airline         -0.039439     -0.015733  0.027917     0.035732
# Date_of_Journey -0.007836     -0.012507 -0.001168    -0.043846
# Source           0.055191      0.020844 -0.192009    -0.225557
# Destination     -0.063608     -0.036830  0.022037     0.337756
# Route           -0.082080      0.010523 -0.062111    -0.437362
# Dep_Time         1.000000     -0.023294  0.041619     0.044536
# Arrival_Time    -0.023294      1.000000  0.027746    -0.097269
# Duration         0.041619      0.027746  1.000000     0.175106
# Total_Stops      0.044536     -0.097269  0.175106     1.000000
# Additional_Info -0.052853      0.017505  0.080151     0.164114
# Price            0.002949      0.027377 -0.144270    -0.571179
#
#                  Additional_Info     Price
# Airline                -0.060802 -0.039520
# Date_of_Journey         0.008382 -0.036942
# Source                 -0.022107  0.015998
# Destination             0.026806 -0.071112
# Route                   0.035216  0.164085
# Dep_Time               -0.052853  0.002949
# Arrival_Time            0.017505  0.027377
# Duration                0.080151 -0.144270
# Total_Stops             0.164114 -0.571179
# Additional_Info         1.000000 -0.065478
# Price                  -0.065478  1.000000

# %%
plt.figure(figsize=(15,12))
sns.heatmap(dfcor,cmap='Blues',annot=True,linewidths=2.5,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
dfcor['Price']
# Out:
# Airline           -0.039520
# Date_of_Journey   -0.036942
# Source             0.015998
# Destination       -0.071112
# Route              0.164085
# Dep_Time           0.002949
# Arrival_Time       0.027377
# Duration          -0.144270
# Total_Stops       -0.571179
# Additional_Info   -0.065478
# Price              1.000000
# Name: Price, dtype: float64

# %%
df.plot(kind='kde',subplots=True,layout=(6,7),figsize=(22,20))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>]], dtype=object)

# %%
df.plot(kind='hist',subplots=True,layout=(6,7),figsize=(22,20))
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>]], dtype=object)

# %% [markdown]
# after the examining of the correlation values, i came to know that the most feature columns are less correlated with the target column but droping these columns will somewhere affect the accuracy of the dataset.

# %% [markdown]
# now checking the outliers in the feature columns of the dataset by the help of boxplot:-

# %%
df.plot(kind='box',subplots=True,layout=(3,8),figsize=(22,20))
# Out:
# Airline               AxesSubplot(0.125,0.657941;0.0824468x0.222059)
# Date_of_Journey    AxesSubplot(0.223936,0.657941;0.0824468x0.222059)
# Source             AxesSubplot(0.322872,0.657941;0.0824468x0.222059)
# Destination        AxesSubplot(0.421809,0.657941;0.0824468x0.222059)
# Route              AxesSubplot(0.520745,0.657941;0.0824468x0.222059)
# Dep_Time           AxesSubplot(0.619681,0.657941;0.0824468x0.222059)
# Arrival_Time       AxesSubplot(0.718617,0.657941;0.0824468x0.222059)
# Duration           AxesSubplot(0.817553,0.657941;0.0824468x0.222059)
# Total_Stops           AxesSubplot(0.125,0.391471;0.0824468x0.222059)
# Additional_Info    AxesSubplot(0.223936,0.391471;0.0824468x0.222059)
# Price              AxesSubplot(0.322872,0.391471;0.0824468x0.222059)
# dtype: object

# %% [markdown]
# there are outliers in the dataset, now the removal of outliers is being done with the help of zscore method:-

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#         Airline  Date_of_Journey    Source  Destination     Route  Dep_Time  \
# 0      0.410675         0.021472  1.658441     2.416665  1.547138  1.686554
# 1      1.260999         1.437532  0.890052     0.973826  0.249797  1.260270
# 2      0.014486         1.561532  0.040555     0.295728  1.175491  0.621792
# 3      0.410675         1.113308  0.890052     0.973826  0.440381  0.917105
# 4      0.410675         1.923866  1.658441     2.416665  1.247649  0.671537
# ...         ...              ...       ...          ...       ...       ...
# 10678  1.686161         1.399420  0.890052     0.973826  0.294728  1.228159
# 10679  1.260999         0.426751  0.890052     0.973826  0.294728  1.391872
# 10680  0.014486         0.426751  1.658441     0.382370  1.547138  0.818247
# 10681  2.565458         1.923866  1.658441     2.416665  1.547138  0.261624
# 10682  1.260999         1.480476  0.040555     0.295728  0.903228  0.376223
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info     Price
# 0          1.921086  0.422875     1.406839         0.499892  1.125548
# 1          0.109117  1.306727     0.253853         0.499892  0.309048
# 2          1.378090  0.810835     0.253853         0.499892  1.039858
# 3          1.370075  1.076557     0.807417         0.499892  0.622202
# 4          1.107627  1.002903     0.807417         0.499892  0.914076
# ...             ...       ...          ...              ...       ...
# 10678      1.173993  0.386047     1.406839         0.499892  1.080006
# 10679      1.312759  0.395254     1.406839         0.499892  1.071765
# 10680      0.138248  0.791146     1.406839         0.499892  0.402951
# 10681      0.205650  0.404461     1.406839         0.499892  0.772246
# 10682      0.766746  1.408001     0.253853         0.499892  0.578151
#
# [10683 rows x 11 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  123,   396,   486,   510,   597,   628,   657,   785,   785,
#          826,   936,   946,   959,   975,  1043,  1196,  1246,  1341,
#         1424,  1466,  1478,  1629,  1654,  1785,  1918,  2055,  2079,
#         2099,  2108,  2405,  2481,  2495,  2495,  2556,  2556,  2618,
#         2635,  2693,  2924,  2924,  3032,  3032,  3111,  3111,  3257,
#         3400,  3535,  3700,  3700,  3788,  4012,  4521,  4521,  4676,
#         4829,  5013,  5013,  5136,  5372,  5372,  5439,  5628,  5662,
#         5701,  5710,  5719,  5738,  5745,  5856,  5986,  6024,  6314,
#         6336,  6407,  6576,  6576,  6588,  6605,  6991,  7351,  7356,
#         7377,  7537,  7554,  7617,  7713,  7724,  7724,  7756,  7902,
#         8020,  8080,  8451,  8470,  8536,  8598,  8856,  8940,  8957,
#         8957,  8990,  9019,  9019,  9193,  9239,  9632,  9657,  9715,
#         9974, 10052, 10113, 10160, 10182, 10189, 10353, 10364, 10364,
#        10383, 10439, 10511, 10511], dtype=int64), array([10, 10, 10, 10, 10, 10, 10,  9, 10, 10, 10, 10, 10, 10,  9, 10, 10,
#        10, 10, 10, 10, 10, 10, 10, 10, 10,  9, 10, 10,  9,  9,  9, 10,  9,
#        10, 10, 10, 10,  9, 10,  9, 10,  9, 10, 10, 10, 10,  9, 10,  9, 10,
#         9, 10, 10, 10,  9, 10, 10,  9, 10, 10,  9, 10, 10, 10, 10, 10, 10,
#        10, 10,  9, 10,  9, 10,  9, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,
#        10,  9, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10, 10,  9, 10, 10,  9,
#        10, 10, 10, 10,  9, 10, 10, 10, 10, 10, 10, 10, 10,  9, 10, 10, 10,
#         9, 10], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0            3               24       0            5     18       211
# 1            1                6       3            0     84        31
# 2            4               43       2            1    118        70
# 3            3               10       3            0     91       164
# 4            3                0       0            5     29       149
# ...        ...              ...     ...          ...    ...       ...
# 10678        0               41       3            0     64       183
# 10679        1               29       3            0     64       193
# 10680        4               29       0            2     18        58
# 10681       10                0       0            5     18        92
# 10682        1               42       2            1    108        85
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# 0               233       240            4                8   3897
# 1               906       336            1                8   7662
# 2               413       106            1                8  13882
# 3              1324       311            0                8   6218
# 4              1237       303            0                8  13302
# ...             ...       ...          ...              ...    ...
# 10678          1259       236            4                8   4107
# 10679          1305       237            4                8   4145
# 10680           824       280            4                8   7229
# 10681           938       238            4                8  12648
# 10682          1124       347            1                8  11753
#
# [10578 rows x 11 columns]

# %%
df=df_new
df
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0            3               24       0            5     18       211
# 1            1                6       3            0     84        31
# 2            4               43       2            1    118        70
# 3            3               10       3            0     91       164
# 4            3                0       0            5     29       149
# ...        ...              ...     ...          ...    ...       ...
# 10678        0               41       3            0     64       183
# 10679        1               29       3            0     64       193
# 10680        4               29       0            2     18        58
# 10681       10                0       0            5     18        92
# 10682        1               42       2            1    108        85
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# 0               233       240            4                8   3897
# 1               906       336            1                8   7662
# 2               413       106            1                8  13882
# 3              1324       311            0                8   6218
# 4              1237       303            0                8  13302
# ...             ...       ...          ...              ...    ...
# 10678          1259       236            4                8   4107
# 10679          1305       237            4                8   4145
# 10680           824       280            4                8   7229
# 10681           938       238            4                8  12648
# 10682          1124       347            1                8  11753
#
# [10578 rows x 11 columns]

# %% [markdown]
# now finding the data loss percentage so that we can see that the dataset is becoming biased or not

# %%
data_loss=((10683-10578)/10683)*100
data_loss
# Out:
# 0.9828699803426004

# %% [markdown]
# as the data loss percentage is 0.98 % so the outliers can be removed as the data is not becoming biased

# %%
df
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0            3               24       0            5     18       211
# 1            1                6       3            0     84        31
# 2            4               43       2            1    118        70
# 3            3               10       3            0     91       164
# 4            3                0       0            5     29       149
# ...        ...              ...     ...          ...    ...       ...
# 10678        0               41       3            0     64       183
# 10679        1               29       3            0     64       193
# 10680        4               29       0            2     18        58
# 10681       10                0       0            5     18        92
# 10682        1               42       2            1    108        85
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info  Price
# 0               233       240            4                8   3897
# 1               906       336            1                8   7662
# 2               413       106            1                8  13882
# 3              1324       311            0                8   6218
# 4              1237       303            0                8  13302
# ...             ...       ...          ...              ...    ...
# 10678          1259       236            4                8   4107
# 10679          1305       237            4                8   4145
# 10680           824       280            4                8   7229
# 10681           938       238            4                8  12648
# 10682          1124       347            1                8  11753
#
# [10578 rows x 11 columns]

# %% [markdown]
# the removal of skewness can't be performed as the dataset is object datatype in nature

# %% [markdown]
# the dataset is being divided into target column and feature column as y and x respectively.

# %%
x=df.iloc[:,:-1]
x
# Out:
#        Airline  Date_of_Journey  Source  Destination  Route  Dep_Time  \
# 0            3               24       0            5     18       211
# 1            1                6       3            0     84        31
# 2            4               43       2            1    118        70
# 3            3               10       3            0     91       164
# 4            3                0       0            5     29       149
# ...        ...              ...     ...          ...    ...       ...
# 10678        0               41       3            0     64       183
# 10679        1               29       3            0     64       193
# 10680        4               29       0            2     18        58
# 10681       10                0       0            5     18        92
# 10682        1               42       2            1    108        85
#
#        Arrival_Time  Duration  Total_Stops  Additional_Info
# 0               233       240            4                8
# 1               906       336            1                8
# 2               413       106            1                8
# 3              1324       311            0                8
# 4              1237       303            0                8
# ...             ...       ...          ...              ...
# 10678          1259       236            4                8
# 10679          1305       237            4                8
# 10680           824       280            4                8
# 10681           938       238            4                8
# 10682          1124       347            1                8
#
# [10578 rows x 10 columns]

# %%
y=df.iloc[:,-1]
y
# Out:
# 0         3897
# 1         7662
# 2        13882
# 3         6218
# 4        13302
#          ...
# 10678     4107
# 10679     4145
# 10680     7229
# 10681    12648
# 10682    11753
# Name: Price, Length: 10578, dtype: int64

# %%
x.shape
# Out:
# (10578, 10)

# %%
y.shape
# Out:
# (10578,)

# %% [markdown]
# performing the standard scaler method for making the data in the scaler format so the machine can easily learn the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x1=sc.fit_transform(x)
x1
# Out:
# array([[-0.41059132,  0.00741708, -1.68101932, ...,  0.42321412,
#          1.39757642,  0.50792348],
#        [-1.25863095, -1.4667397 ,  0.88428326, ...,  1.30882055,
#         -0.25977373,  0.50792348],
#        [ 0.0134285 ,  1.56347146,  0.0291824 , ..., -0.81294486,
#         -0.25977373,  0.50792348],
#        ...,
#        [ 0.0134285 ,  0.41690508, -1.68101932, ...,  0.7922168 ,
#          1.39757642,  0.50792348],
#        [ 2.55754738, -1.95812529, -1.68101932, ...,  0.40476399,
#          1.39757642,  0.50792348],
#        [-1.25863095,  1.48157386,  0.0291824 , ...,  1.41029629,
#         -0.25977373,  0.50792348]])

# %%
x=pd.DataFrame(x1)
x
# Out:
#               0         1         2         3         4         5         6  \
# 0     -0.410591  0.007417 -1.681019  2.480267 -1.574442  1.687609 -1.923082
# 1     -1.258631 -1.466740  0.884283 -0.972964  0.238846 -1.261140  0.108134
# 2      0.013428  1.563471  0.029182 -0.282317  1.172964 -0.622244 -1.379815
# 3     -0.410591 -1.139149  0.884283 -0.972964  0.431165  0.917658  1.369721
# 4     -0.410591 -1.958125 -1.681019  2.480267 -1.272227  0.671929  1.107142
# ...         ...       ...       ...       ...       ...       ...       ...
# 10573 -1.682651  1.399676  0.884283 -0.972964 -0.310635  1.228915  1.173541
# 10574 -1.258631  0.416905  0.884283 -0.972964 -0.310635  1.392734  1.312376
# 10575  0.013428  0.416905 -1.681019  0.408329 -1.574442 -0.818827 -0.139355
# 10576  2.557547 -1.958125 -1.681019  2.480267 -1.574442 -0.261841  0.204715
# 10577 -1.258631  1.481574  0.029182 -0.282317  0.898224 -0.376515  0.766091
#
#               7         8         9
# 0      0.423214  1.397576  0.507923
# 1      1.308821 -0.259774  0.507923
# 2     -0.812945 -0.259774  0.507923
# 3      1.078194 -0.812224  0.507923
# 4      1.004393 -0.812224  0.507923
# ...         ...       ...       ...
# 10573  0.386314  1.397576  0.507923
# 10574  0.395539  1.397576  0.507923
# 10575  0.792217  1.397576  0.507923
# 10576  0.404764  1.397576  0.507923
# 10577  1.410296 -0.259774  0.507923
#
# [10578 rows x 10 columns]

# %%
x.shape
# Out:
# (10578, 10)

# %% [markdown]
# the important library are called for the modeling and thus predicting the columns.
# the model which we are calling is regression as the target column is the continuous data.

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# splitting the dataset for the machine to learn in the form of train and test

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=447,test_size=.25)

# %%
x_train.shape
# Out:
# (7933, 10)

# %%
x_test.shape
# Out:
# (2645, 10)

# %%
y_train.shape
# Out:
# (7933,)

# %%
y_test.shape
# Out:
# (2645,)

# %% [markdown]
# finding out the best random state

# %%
maxsc=0
maxrs=0
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lm=LinearRegression()
    lm.fit(x_train,y_train)
    predlm=lm.predict(x_test)
    score=lm.score(x_train,y_train)
    if score>maxsc:
        maxsc=score
        maxrs=i
print(maxsc)
print(maxrs)
# Out:
# 0.42135476515047743
# 447

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
predlm=lm.predict(x_test)
print('mean absolute error:',mean_absolute_error(y_test,predlm))
print('mean squared error:',mean_squared_error(y_test,predlm))
print(lm.score(x_train,y_train))
print(r2_score(y_test,predlm))
# Out:
# mean absolute error: 2515.0891580147772
# mean squared error: 9960104.610168966
# 0.4063507123683625
# 0.3970547196102462

# %%
ls=Lasso(alpha=.0001)
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
print(ls.coef_)
# Out:
# 0.4063507123683545
# [  -80.58164875    44.38712229  -359.08630062    35.74064309
#    -58.95211134   184.32078257  -120.92511256  -348.88003786
#  -2639.02951614   289.23650231]

# %%
plt.figure(figsize=(7,5))
plt.bar(x.columns,ls.coef_)
# Out:
# <BarContainer object of 10 artists>

# %%
rg=Ridge(alpha=.0001)
rg.fit(x_train,y_train)
print(rg.score(x_train,y_train))
print(rg.coef_)
# Out:
# 0.4063507123683623
# [  -80.58172773    44.38729034  -359.08634263    35.740744
#    -58.95227572   184.32089142  -120.92522201  -348.8801281
#  -2639.02971213   289.23663918]

# %%
plt.figure(figsize=(7,5))
plt.bar(x.columns,rg.coef_)
# Out:
# <BarContainer object of 10 artists>

# %%
kernel_list=['linear','poly','rbf']
for i in kernel_list:
    svr=SVR(kernel=i)
    svr.fit(x_train,y_train)
    print(svr.score(x_train,y_train))
# Out:
# 0.3385616815253347
# 0.05494738003431365
# 0.05230667682555612

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predrfr=rfr.predict(x_test)
print('predicted price=',predrfr)
print('actual price=',y_test)
print('score',rfr.score(x_train,y_train))
# Out:
# predicted price= [ 9812.58  12619.105 10436.34  ...  3895.55   9811.69  12365.9  ]
# actual price= 5376     8781
# 470     13082
# 7912    10368
# 3613     4591
# 7566     9319
#         ...
# 1313     2575
# 7579     3841
# 2805     3687
# 5230     5177
# 5078    12452
# Name: Price, Length: 2645, dtype: int64
# score 0.9834244091202132

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predrfr,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('actual price',fontsize=14)
plt.ylabel('predicted price',fontsize=14)
plt.title('random forest regressor',fontsize=18)
plt.show()

# %%
import pickle
filename='flightprice.pkl'
pickle.dump(rfr,open(filename,'wb'))

# %% [markdown]
# the best model for the prediction of flight prices is the random forest regressor for the
# machine learning, the score achieved is 98.3.the best line is shown according to the random forest regressor model
